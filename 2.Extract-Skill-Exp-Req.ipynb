# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from glob import glob
import spacy
import re
import string
import os
import nltk
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings 
warnings.filterwarnings('ignore') 
#nltk.download('wordnet')
#nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()

# %%
model_ner = spacy.load('./model-best/')

# %% [markdown]
# ## Parsing / Extract Skill

# %%
def merge_tokens(df):
    merged_tokens = []
    current_token = ''
    current_label = ''
    
    for i, row in df.iterrows():
        token = lemmatizer.lemmatize(row['tokens'].lower())
        label = row['label']
        
        if label.startswith('B-'):
            if current_token:
                merged_tokens.append((current_token, current_label))
            current_token = token
            current_label = label
        elif label.startswith('I-') and current_label[2:] == label[2:]:
            current_token += ' ' + token
        else:
            current_token = ''
            current_label = ''
    
    if current_token:
        merged_tokens.append((current_token, current_label))

    merged_tokens = list(set(merged_tokens))
    
    return merged_tokens

# %%
def parsing_ner(text):
    doc = model_ner(text)
    doc_json = doc.to_json()
    doc_text = doc_json['text']
    
    df_tokens = pd.DataFrame(doc_json['tokens'])
    df_tokens['tokens'] = df_tokens[['start', 'end']].apply(
        lambda x: doc_text[x[0]: x[1]], axis=1
    )
    
    if not doc_json['ents']:
        return {}
    
    right_table = pd.DataFrame(doc_json['ents'])[['start', 'label']]
    df_tokens = pd.merge(df_tokens, right_table, how='left', on='start')
    
    df_tokens = df_tokens.query('label == label')
    merged = merge_tokens(df_tokens)
    print(df_tokens) 
    
    merged_df = pd.DataFrame(merged, columns=['tokens', 'label'])
    result = merged_df.groupby('label')['tokens'].apply(list).to_dict()
    
    return result

# %% [markdown]
# ## Import data and Data preparation

# %%
job_desc = pd.read_csv('./Data/job_listings_DA.csv')
job_desc.head()
# Out:
#                                 Title                       Company  \
# 0                        Data Analyst          Yayasan Hutan Tropis
# 1                        DATA ANALYST        PT Karya Anugerah Jaya
# 2         Data Analyst Jr. Specialist  PT Bussan Auto Finance (BAF)
# 3                        Data Analyst                  PT SMART,Tbk
# 4  Data Analyst - ERP Staff (JAKARTA)           PT Allure Alluminio
#
#                                          Description
# 0  Data Analyst: Collect, clean and analyze infor...
# 1  KUALIFIKASI :: DESKRIPSI PEKERJAAN :: NOTE : P...
# 2  Job Description : : Qualification : : Job Desc...
# 3  Job Description Summary:: Job Description:: Jo...
# 4  ERP(Dynamics 365 Business Central): Bersedia d...

# %%
results = job_desc['Description'].apply(parsing_ner)
results_df = pd.DataFrame(results.tolist(), index=job_desc.index)
job_desc = job_desc.join(results_df)
job_desc = job_desc.fillna(0)

for column in results_df.columns:
   job_desc[column] = job_desc[column]

print(job_desc.head())
# Out:
#       id  start   end   dep  head           tokens     label
# 8      8     41    52  ROOT     8      information  I-HSkill
# 19    19    113   122  ROOT    19        processes  I-HSkill
# 28    28    163   165  ROOT    28               of  B-HSkill
# 61    61    335   345  ROOT    61       ecosystems  I-HSkill
# 139  139    748   755  ROOT   139          complex  B-HSkill
# 140  140    756   760  ROOT   140             data  I-HSkill
# 141  141    761   765  ROOT   141             sets    I-Tech
# 156  156    854   863  ROOT   156        expertise  I-HSkill
# 158  158    867   872  ROOT   158            Excel    B-Tech
# 164  164    903   909  ROOT   164           macros  I-HSkill
# 166  166    914   917  ROOT   166              VBA    B-Tech
# 168  168    919   923  ROOT   168             will  B-HSkill
# 174  174    955   965  ROOT   174       optimizing  B-HSkill
# 176  176    970   974  ROOT   176             data  I-HSkill
# 177  177    975   984  ROOT   177        processes  I-HSkill
# 186  186   1024  1034  ROOT   186       PowerPoint    B-Tech
# 193  193   1067  1076  ROOT   193        impactful  I-HSkill
# 216  216   1216  1226  ROOT   216       seamlessly  I-HSkill
# 227  227   1291  1297  ROOT   227           skills  I-HSkill
# 256  256   1463  1470  ROOT   256          dynamic  B-HSkill
# 257  257   1471  1482  ROOT   257      environment  I-HSkill
# 293  293   1653  1664  ROOT   293      information  I-HSkill
# 309  309   1734  1742  ROOT   309         innovate  I-HSkill
# 377  377   2123  2138  ROOT   377  recommendations  B-SSkill
# 379  379   2147  2156  ROOT   379        companies  I-HSkill
# 381  381   2160  2169  ROOT   381        transform  I-HSkill
# 389  389   2208  2216  ROOT   389         insights  I-HSkill
# 406  406   2305  2308  ROOT   406              our  B-HSkill
# 419  419   2385  2389  ROOT   419             palm    B-Tech
# 422  422   2395  2398  ROOT   422              soy    B-Tech
# 424  424   2400  2405  ROOT   424            cocoa  B-HSkill
# 439  439   2476  2481  ROOT   439            Ghana    B-Tech
# 466  466   2623  2632  ROOT   466        processes  I-HSkill
# 474  474   2661  2667  ROOT   474           Bahasa  B-SSkill
#     id  start  end   dep  head         tokens     label
# 7    7     38   42  ROOT     7           NOTE    B-Tech
# 30  30    170  174  ROOT    30           Data  B-HSkill
# 31  31    175  182  ROOT    31        Analyst  I-HSkill
# 47  47    276  280  ROOT    47           data  I-HSkill
# 50  50    293  300  ROOT    50        program  B-HSkill
# 51  51    301  310  ROOT    51      Microsoft    B-Tech
# 52  52    311  317  ROOT    52         Office    I-Tech
# 54  54    322  330  ROOT    54       Familiar  B-HSkill
# 56  56    338  346  ROOT    56       Accurate  B-HSkill
# 60  60    368  378  ROOT    60     komunikasi  B-SSkill
# 62  62    383  396  ROOT    62  interpersonal  B-SSkill
# 66  66    409  414  ROOT    66          Jujur  B-SSkill
# 68  68    416  422  ROOT    68         teliti  B-SSkill
# 70  70    425  437  ROOT    70   berinisiatif  B-SSkill
# 72  72    439  447  ROOT    72       proaktif  B-SSkill
# 74  74    452  463  ROOT    74    bertanggung  B-SSkill
#       id  start   end   dep  head      tokens     label
# 0      0      0     3  ROOT     0         Job  B-HSkill
# 31    31    210   214  ROOT    31        data  I-HSkill
# 59    59    399   402  ROOT    59         tim  B-SSkill
# 70    70    461   468  ROOT    70     peluang  B-SSkill
# 123  123    801   808  ROOT   123     Analyst  I-HSkill
# 130  130    854   862  ROOT   130    Services  I-HSkill
# 147  147    959   964  ROOT   147       tools  B-HSkill
# 150  150    982   985  ROOT   150         SQL    B-Tech
# 152  152    987   992  ROOT   152       Excel    B-Tech
# 168  168   1076  1079  ROOT   168         tim  B-SSkill
# 175  175   1124  1134  ROOT   175  komunikasi  B-SSkill
#       id  start   end   dep  head        tokens     label
# 0      0      0     3  ROOT     0           Job  B-HSkill
# 2      2     16    23  ROOT     2       Summary  I-HSkill
# 52    52    289   299  ROOT    52    compliance  I-HSkill
# 69    69    394   397  ROOT    69           for  B-HSkill
# 78    78    445   453  ROOT    78      reliable  B-HSkill
# 79    79    454   466  ROOT    79  verification  I-HSkill
# 92    92    555   566  ROOT    92   Description  I-HSkill
# 130  130    764   772  ROOT   130      validate  I-HSkill
# 131  131    773   781  ROOT   131      supplier  B-HSkill
# 198  198   1142  1149  ROOT   198       desktop  I-HSkill
# 216  216   1256  1264  ROOT   216      external  B-HSkill
# 236  236   1366  1372  ROOT   236        verify  B-HSkill
# 246  246   1423  1428  ROOT   246         field  I-HSkill
#     id  start  end   dep  head      tokens     label
# 41  41    277  285  ROOT    41    analisis  B-HSkill
# 47  47    312  320  ROOT    47    mengolah  B-HSkill
# 61  61    404  414  ROOT    61  komunikasi  B-SSkill
# 68  68    448  455  ROOT    68     mandiri  B-SSkill
# 71  71    469  472  ROOT    71         tim  B-SSkill
#       id  start  end   dep  head          tokens     label
# 0      0      0    3  ROOT     0             Job  B-HSkill
# 13    13     74   78  ROOT    13            data  B-HSkill
# 14    14     79   87  ROOT    14        existing  I-HSkill
# 19    19    118  125  ROOT    19         insight  B-HSkill
# 42    42    262  271  ROOT    42       databases  B-HSkill
# 44    44    273  285  ROOT    44    troubleshoot  B-HSkill
# 48    48    298  312  ROOT    48  mengoptimalkan  B-HSkill
# 57    57    353  357  ROOT    57            data  I-HSkill
# 85    85    545  549  ROOT    85            data  B-HSkill
# 86    86    550  556  ROOT    86          mining  I-HSkill
# 97    97    615  624  ROOT    97       Microsoft    B-Tech
# 98    98    625  630  ROOT    98           Excel    I-Tech
# 100  100    632  635  ROOT   100             SQL    B-Tech
# 102  102    637  644  ROOT   102         Tableau    B-Tech
# 105  105    652  654  ROOT   105              BI    I-Tech
# 107  107    659  665  ROOT   107          Google    B-Tech
# 108  108    666  670  ROOT   108            Data  I-HSkill
# 143  143    879  886  ROOT   143         problem  B-SSkill
# 144  144    887  894  ROOT   144         solving  I-SSkill
#       id  start   end   dep  head       tokens     label
# 9      9     66    77  ROOT     9  Requirement  I-HSkill
# 27    27    166   174  ROOT    27     research  I-HSkill
# 37    37    219   227  ROOT    37     proposed    B-Tech
# 52    52    305   311  ROOT    52       update  B-HSkill
# 55    55    327   329  ROOT    55           of  I-HSkill
# 66    66    379   383  ROOT    66         land    B-Tech
# 68    68    385   391  ROOT    68       permit    B-Tech
# 78    78    423   433  ROOT    78   analytical  B-HSkill
# 109  109    613   619  ROOT   109       review    B-Tech
# 131  131    776   782  ROOT   131       issues  I-HSkill
# 219  219   1253  1255  ROOT   219           an  B-HSkill
# 232  232   1326  1336  ROOT   232   analytical  I-HSkill
# 242  242   1396  1405  ROOT   242    Microsoft    B-Tech
# 246  246   1422  1427  ROOT   246        Point  I-HSkill
# 264  264   1512  1516  ROOT   264         self  B-SSkill
#       id  start  end   dep  head        tokens     label
# 22    22    122  127  ROOT    22         roles    B-Tech
# 48    48    270  276  ROOT    48        timely  I-HSkill
# 52    52    296  301  ROOT    52         lists  I-HSkill
# 59    59    338  342  ROOT    59          data  I-HSkill
# 65    65    379  387  ROOT    65      complete  B-HSkill
# 86    86    490  495  ROOT    86         input    B-Tech
# 87    87    496  505  ROOT    87     processes  I-HSkill
# 92    92    521  533  ROOT    92  completeness  I-HSkill
# 98    98    571  577  ROOT    98        orders    B-Tech
# 102  102    592  601  ROOT   102     necessary  B-HSkill
# 103  103    602  613  ROOT   103   information  I-HSkill
#       id  start  end   dep  head         tokens     label
# 9      9     41   45  ROOT     9           join  I-HSkill
# 33    33    167  171  ROOT    33           well  B-SSkill
# 46    46    222  232  ROOT    46     experience    B-Tech
# 59    59    292  296  ROOT    59           data  B-HSkill
# 60    60    297  305  ROOT    60       analysis  B-HSkill
# 61    61    306  311  ROOT    61          tools  I-HSkill
# 63    63    316  325  ROOT    63      databases  B-HSkill
# 94    94    507  514  ROOT    94        Ability  I-HSkill
# 107  107    584  597  ROOT   107  methodologies  I-HSkill
# 115  115    637  646  ROOT   115      databases  I-HSkill
# 125  125    694  700  ROOT   125         skills  B-SSkill
#       id  start   end   dep  head         tokens     label
# 9      9     51    60  ROOT     9      ecosystem  I-HSkill
# 46    46    282   290  ROOT    46       services  I-HSkill
# 48    48    292   296  ROOT    48           food  B-HSkill
# 53    53    319   328  ROOT    53      logistics  B-HSkill
# 63    63    379   387  ROOT    63       services  I-HSkill
# 66    66    400   405  ROOT    66          Gojek    B-Tech
# 88    88    521   530  ROOT    88      ecosystem  I-HSkill
# 112  112    652   660  ROOT   112       platform  I-HSkill
# 143  143    834   843  ROOT   143      logistics  B-HSkill
# 152  152    881   887  ROOT   152         impact  I-HSkill
# 156  156    898   903  ROOT   156          Gojek    B-Tech
# 160  160    920   929  ROOT   160      resolving  B-HSkill
# 161  161    930   938  ROOT   161       consumer  I-HSkill
# 178  178   1039  1047  ROOT   178       services  I-HSkill
# 195  195   1161  1169  ROOT   195       services  I-HSkill
# 202  202   1208  1216  ROOT   202       services  I-HSkill
# 221  221   1316  1321  ROOT   221          GoBiz    B-Tech
# 273  273   1584  1588  ROOT   273           GoTo    B-Tech
# 285  285   1647  1650  ROOT   285            our  B-HSkill
# 288  288   1670  1678  ROOT   288       websites  I-HSkill
# 368  368   2128  2136  ROOT   368       adoption  I-HSkill
# 374  374   2157  2165  ROOT   374       analysis  B-HSkill
# 375  375   2166  2171  ROOT   375          using  I-HSkill
# 377  377   2184  2189  ROOT   377          tools  I-HSkill
# 379  379   2191  2195  ROOT   379           data  B-HSkill
# 380  380   2196  2209  ROOT   380  visualization  I-HSkill
# 383  383   2215  2223  ROOT   383       business  I-HSkill
# 387  387   2236  2243  ROOT   387        product  B-HSkill
# 424  424   2464  2472  ROOT   424       delivery  I-HSkill
# 431  431   2509  2513  ROOT   431           data  I-HSkill
# 445  445   2599  2610  ROOT   445    requirement  I-HSkill
# 460  460   2686  2695  ROOT   460      analytics  I-HSkill
# 477  477   2782  2785  ROOT   477            SQL    B-Tech
# 479  479   2788  2792  ROOT   479           data  B-HSkill
# 480  480   2793  2806  ROOT   480  visualization  I-HSkill
# 482  482   2811  2823  ROOT   482   dashboarding  I-HSkill
# 503  503   2938  2946  ROOT   503       thinking  I-HSkill
# 531  531   3098  3106  ROOT   531       analysis  I-HSkill
# 535  535   3116  3122  ROOT   535         design  I-HSkill
# 541  541   3156  3169  ROOT   541  visualization  B-HSkill
# 544  544   3187  3192  ROOT   544          tools  I-HSkill
# 551  551   3219  3225  ROOT   551         Google    B-Tech
# 552  552   3226  3230  ROOT   552           Data  I-HSkill
# 553  553   3231  3237  ROOT   553         Studio    I-Tech
# 557  557   3250  3256  ROOT   557         Python    B-Tech
#       id  start   end   dep  head          tokens     label
# 4      4     33    43  ROOT     4      understand  B-HSkill
# 29    29    180   188  ROOT    29        analysis  I-HSkill
# 31    31    190   204  ROOT    31  classification  B-HSkill
# 34    34    210   220  ROOT    34      clustering  I-HSkill
# 40    40    249   257  ROOT    40        analysis  I-HSkill
# 42    42    262   269  ROOT    42         feature  B-HSkill
# 43    43    270   281  ROOT    43     engineering  I-HSkill
# 47    47    304   312  ROOT    47        insights  I-HSkill
# 55    55    351   362  ROOT    55     statistical  B-HSkill
# 56    56    363   370  ROOT    56         methods  I-HSkill
# 60    60    392   402  ROOT    60      algorithms  I-HSkill
# 63    63    413   422  ROOT    63       effective  I-HSkill
# 64    64    423   427  ROOT    64            data  I-HSkill
# 70    70    456   460  ROOT    70            data  I-HSkill
# 71    71    461   475  ROOT    71  visualizations  I-HSkill
# 75    75    486   496  ROOT    75      dashboards  B-HSkill
# 80    80    519   530  ROOT    80     communicate  B-HSkill
# 81    81    531   539  ROOT    81        insights  I-HSkill
# 90    90    585   591  ROOT    90          latest  B-HSkill
# 91    91    592   596  ROOT    91            data  I-HSkill
# 114  114    708   715  ROOT   114         Applied  B-HSkill
# 120  120    742   747  ROOT   120           field  I-HSkill
# 125  125    766   772  ROOT   125          Python    B-Tech
# 129  129    783   787  ROOT   129            data  I-HSkill
# 140  140    847   854  ROOT   140         machine  I-HSkill
# 142  142    864   874  ROOT   142      algorithms  I-HSkill
# 146  146    882   892  ROOT   146      regression  B-HSkill
# 148  148    894   904  ROOT   148      clustering  B-HSkill
# 160  160    957   961  ROOT   160            data  I-HSkill
# 162  162    976   981  ROOT   162           tools  I-HSkill
# 165  165    990   997  ROOT   165         Tableau    B-Tech
# 168  168   1005  1007  ROOT   168              BI    I-Tech
# 170  170   1009  1019  ROOT   170      Matplotlib    B-Tech
# 183  183   1077  1087  ROOT   183      frameworks    I-Tech
# 185  185   1093  1103  ROOT   185      TensorFlow    B-Tech
# 187  187   1105  1112  ROOT   187         PyTorch    B-Tech
# 189  189   1114  1116  ROOT   189              or    B-Tech
# 202  202   1163  1173  ROOT   202      hypothesis  B-HSkill
# 208  208   1205  1213  ROOT   208        analysis    B-Tech
# 209  209   1214  1221  ROOT   209         methods  I-HSkill
# 214  214   1239  1248  ROOT   214       deploying  I-HSkill
# 227  227   1325  1334  ROOT   227       platforms  I-HSkill
# 231  231   1342  1348  ROOT   231          Hadoop    B-Tech
# 233  233   1350  1355  ROOT   233           Spark    B-Tech
# 237  237   1366  1375  ROOT   237       platforms  I-HSkill
# 241  241   1383  1386  ROOT   241             AWS    B-Tech
# 243  243   1388  1394  ROOT   243          Google    B-Tech
# 250  250   1421  1424  ROOT   250             SQL  B-HSkill
# 251  251   1425  1428  ROOT   251             for  B-HSkill
# 253  253   1438  1448  ROOT   253      management  I-HSkill
# 260  260   1482  1486  ROOT   260            data  I-HSkill
# 261  261   1487  1498  ROOT   261     engineering  I-HSkill
# 264  264   1509  1519  ROOT   264      techniques  I-HSkill
# 275  275   1577  1585  ROOT   275        Flexible  B-HSkill
#       id  start   end   dep  head       tokens     label
# 47    47    298   309  ROOT    47  warehousing  I-HSkill
# 50    50    323   326  ROOT    50          ETL    B-Tech
# 54    54    337   346  ROOT    54    Transform    B-Tech
# 56    56    348   352  ROOT    56         Load    B-Tech
# 97    97    609   613  ROOT    97         data  I-HSkill
# 99    99    615   623  ROOT    99     analisis  B-HSkill
# 117  117    731   739  ROOT   117     industri  I-HSkill
# 136  136    843   847  ROOT   136         Data  B-HSkill
# 159  159    965   973  ROOT   159     platform  B-HSkill
# 160  160    974   979  ROOT   160        cloud  I-HSkill
# 162  162    988   991  ROOT   162          AWS    B-Tech
# 164  164    993   999  ROOT   164       Google    B-Tech
# 165  165   1000  1005  ROOT   165        Cloud    I-Tech
# 168  168   1012  1017  ROOT   168        Azure    B-Tech
# 176  176   1059  1062  ROOT   176          SQL    B-Tech
# 181  181   1090  1101  ROOT   181  pemrograman  B-HSkill
# 185  185   1113  1119  ROOT   185       Python    B-Tech
# 187  187   1121  1122  ROOT   187            R    B-Tech
# 195  195   1162  1166  ROOT   195         data  I-HSkill
# 199  199   1178  1185  ROOT   199      Tableau    B-Tech
# 202  202   1193  1195  ROOT   202           BI    I-Tech
#       id  start   end   dep  head     tokens     label
# 74    74    431   434  ROOT    74        THR    B-Tech
# 108  108    624   628  ROOT   108       data  I-HSkill
# 109  109    629   637  ROOT   109   customer  I-HSkill
# 114  114    670   674  ROOT   114       data  B-HSkill
# 139  139    823   827  ROOT   139       data  I-HSkill
# 188  188   1150  1159  ROOT   188  penutupan  B-SSkill
# 199  199   1213  1219  ROOT   199     upload  B-HSkill
# 239  239   1408  1416  ROOT   239   software  B-HSkill
# 240  240   1417  1425  ROOT   240   business  I-HSkill
# 244  244   1453  1455  ROOT   244         BI  I-HSkill
# 274  274   1627  1635  ROOT   274   software  B-HSkill
# 275  275   1636  1638  ROOT   275         BI  I-HSkill
# 277  277   1643  1648  ROOT   277      excel  B-HSkill
# 287  287   1685  1692  ROOT   287    analisa  B-SSkill
# 294  294   1715  1721  ROOT   294     detail  B-SSkill
#       id  start   end   dep  head         tokens     label
# 12    12     84    92  ROOT    12       Software  B-HSkill
# 13    13     93   104  ROOT    13    Development  I-HSkill
# 36    36    250   258  ROOT    36       database  B-HSkill
# 68    68    405   413  ROOT    68       Business  B-HSkill
# 84    84    506   509  ROOT    84            tim  B-SSkill
# 92    92    550   562  ROOT    92   pengembangan  B-HSkill
# 93    93    563   571  ROOT    93       aplikasi  I-HSkill
# 97    97    585   595  ROOT    97     Functional  B-HSkill
# 98    98    596   609  ROOT    98  Specification  I-HSkill
# 99    99    610   618  ROOT    99       Document  I-HSkill
# 115  115    722   727  ROOT   115          fitur  B-SSkill
# 146  146    902   914  ROOT   146   pengembangan  B-HSkill
# 147  147    915   923  ROOT   147       aplikasi  I-HSkill
# 151  151    937   947  ROOT   151     Functional  B-HSkill
# 152  152    948   961  ROOT   152  Specification  I-HSkill
# 153  153    962   970  ROOT   153       Document  I-HSkill
# 169  169   1073  1078  ROOT   169          fitur  B-SSkill
# 198  198   1258  1269  ROOT   198    Engineering  B-HSkill
# 221  221   1393  1396  ROOT   221            FSD    B-Tech
# 224  224   1409  1422  ROOT   224  Specification  I-HSkill
# 225  225   1423  1431  ROOT   225       Document  I-HSkill
# 228  228   1437  1440  ROOT   228            TRD    B-Tech
# 232  232   1464  1472  ROOT   232       Document    I-Tech
# 237  237   1490  1496  ROOT   237         update  B-HSkill
# 248  248   1560  1567  ROOT   248        analisa  B-SSkill
# 295  295   1886  1896  ROOT   295     automation  B-HSkill
# 310  310   1958  1968  ROOT   310     komunikasi  B-SSkill
# 319  319   2032  2040  ROOT   319       aplikasi  I-HSkill
# 354  354   2275  2279  ROOT   354           team  B-SSkill
# 367  367   2363  2370  ROOT   367        product  B-HSkill
# 391  391   2537  2549  ROOT   391   pengembangan  B-HSkill
# 392  392   2550  2558  ROOT   392       aplikasi  I-HSkill
# 396  396   2578  2584  ROOT   396         detail  B-SSkill
# 453  453   2980  2986  ROOT   453         issues  B-HSkill
#       id  start  end   dep  head      tokens     label
# 16    16     88   98  ROOT    16  memelihara  B-HSkill
# 18    18    106  110  ROOT    18        data  I-HSkill
# 22    22    131  139  ROOT    22    database  B-HSkill
# 75    75    487  496  ROOT    75   penetrasi  B-HSkill
# 111  111    697  701  ROOT   111        data  I-HSkill
#       id  start  end   dep  head     tokens     label
# 9      9     44   49  ROOT     9      Excel    B-Tech
# 25    25    138  143  ROOT    25      entry  B-HSkill
# 26    26    144  148  ROOT    26       data  I-HSkill
# 40    40    238  245  ROOT    40    filling  B-HSkill
# 50    50    294  297  ROOT    50        PPN    B-Tech
# 54    54    304  309  ROOT    54      Biaya    B-Tech
# 56    56    311  320  ROOT    56  Pembelian    B-Tech
# 60    60    333  339  ROOT    60     hutang    B-Tech
# 96    96    507  515  ROOT    96   database  B-HSkill
# 98    98    520  524  ROOT    98       data  B-HSkill
# 106  106    558  563  ROOT   106      Excel    B-Tech
# 113  113    583  588  ROOT   113      Jujur  B-SSkill
# 122  122    621  624  ROOT   122        tim  B-SSkill
#       id  start   end   dep  head        tokens     label
# 8      8     51    54  ROOT     8           Job    B-Tech
# 9      9     55    67  ROOT     9  Descriptions  I-HSkill
# 57    57    314   322  ROOT    57      Software  I-HSkill
# 74    74    406   416  ROOT    74    analytical  B-HSkill
# 86    86    483   490  ROOT    86       offline  B-HSkill
# 88    88    504   512  ROOT    88      channels  I-HSkill
# 95    95    548   552  ROOT    95          OTAs    B-Tech
# 98    98    555   561  ROOT    98        direct  B-HSkill
# 107  107    607   611  ROOT   107          data  I-HSkill
# 116  116    656   665  ROOT   116     effective  I-HSkill
# 122  122    702   709  ROOT   122       actions  I-HSkill
# 133  133    766   775  ROOT   133     inventory  B-HSkill
# 139  139    808   818  ROOT   139    techniques  I-HSkill
# 149  149    873   881  ROOT   149      optimize  B-HSkill
# 150  150    882   891  ROOT   150     inventory  I-HSkill
# 157  157    920   926  ROOT   157        Update    B-Tech
# 175  175   1037  1044  ROOT   175       revenue  I-HSkill
#       id  start   end   dep  head         tokens     label
# 5      5     23    30  ROOT     5        healthy  B-HSkill
# 20    20    103   110  ROOT    20        comment    B-Tech
# 26    26    141   142  ROOT    26              @    I-Tech
# 66    66    363   370  ROOT    66        healthy  B-HSkill
# 73    73    401   409  ROOT    73       products  I-HSkill
# 84    84    455   461  ROOT    84         Europe    B-Tech
# 107  107    615   622  ROOT   107        focused  I-HSkill
# 115  115    685   695  ROOT   115     technology  I-HSkill
# 127  127    756   766  ROOT   127     production    B-Tech
# 133  133    799   811  ROOT   133   technologies  I-HSkill
# 177  177   1046  1054  ROOT   177       products  I-HSkill
# 208  208   1248  1260  ROOT   208   Consultation  I-HSkill
# 214  214   1283  1293  ROOT   214     experience  I-HSkill
# 221  221   1328  1335  ROOT   221        provide  B-HSkill
# 236  236   1462  1474  ROOT   236   Descriptions  I-HSkill
# 242  242   1504  1508  ROOT   242           data  I-HSkill
# 249  249   1539  1545  ROOT   249         online  B-HSkill
# 250  250   1546  1555  ROOT   250      databases  I-HSkill
# 256  256   1580  1588  ROOT   256       datasets  I-HSkill
# 260  260   1601  1605  ROOT   260           data  I-HSkill
# 267  267   1640  1644  ROOT   267           data  I-HSkill
# 270  270   1651  1659  ROOT   270       cleaning  I-HSkill
# 273  273   1665  1669  ROOT   273           data  I-HSkill
# 291  291   1766  1770  ROOT   291           Time  B-HSkill
# 294  294   1778  1786  ROOT   294       analysis  I-HSkill
# 296  296   1788  1798  ROOT   296     Regression  B-HSkill
# 297  297   1799  1807  ROOT   297       analysis  I-HSkill
# 300  300   1811  1820  ROOT   300      Visualize    B-Tech
# 302  302   1825  1829  ROOT   302           data  I-HSkill
# 303  303   1830  1835  ROOT   303          using  I-HSkill
# 304  304   1836  1841  ROOT   304          tools  I-HSkill
# 306  306   1843  1848  ROOT   306          excel    B-Tech
# 308  308   1850  1857  ROOT   308        tableau    B-Tech
# 316  316   1885  1893  ROOT   316       insights  I-HSkill
# 348  348   2073  2077  ROOT   348           Data  I-HSkill
# 359  359   2143  2156  ROOT   359  visualization  I-HSkill
# 365  365   2189  2193  ROOT   365           data  I-HSkill
# 366  366   2194  2202  ROOT   366       analysis    B-Tech
# 367  367   2203  2208  ROOT   367          tools  I-HSkill
# 379  379   2268  2276  ROOT   379       products  B-HSkill
# 385  385   2304  2308  ROOT   385           good  B-HSkill
# 386  386   2309  2319  ROOT   386     analytical  I-HSkill
# 392  392   2355  2359  ROOT   392           data  I-HSkill
# 400  400   2392  2403  ROOT   400    statistical  I-HSkill
# 403  403   2419  2427  ROOT   403       analysis  I-HSkill
# 411  411   2457  2461  ROOT   411           both  B-HSkill
# 420  420   2497  2504  ROOT   420        comment    B-Tech
# 429  429   2558  2566  ROOT   429       benefits  I-HSkill
#       id  start  end   dep  head     tokens     label
# 58    58    277  282  ROOT    58      field  I-HSkill
# 67    67    338  342  ROOT    67       data  I-HSkill
# 75    75    371  380  ROOT    75  knowledge  I-SSkill
# 77    77    384  387  ROOT    77        Ms.    B-Tech
# 78    78    388  393  ROOT    78      Excel    I-Tech
# 86    86    422  427  ROOT    86      Basic    B-Tech
# 91    91    446  452  ROOT    91     Google    B-Tech
# 92    92    453  459  ROOT    92     Sheets    I-Tech
# 97    97    482  488  ROOT    97     skills    I-Tech
# 106  106    533  542  ROOT   106  including  B-HSkill
# 163  163    836  840  ROOT   163       Data  I-HSkill
# 189  189    989  997  ROOT   189   accuracy  I-HSkill
#       id  start   end   dep  head      tokens     label
# 14    14    103   113  ROOT    14  promotions  B-HSkill
# 16    16    115   122  ROOT    16     rewards  B-HSkill
# 38    38    239   243  ROOT    38        data  I-HSkill
# 81    81    510   519  ROOT    81   contracts    I-Tech
# 88    88    543   549  ROOT    88      Update    B-Tech
# 91    91    563   571  ROOT    91    database  B-HSkill
# 92    92    572   574  ROOT    92          by  I-HSkill
# 176  176   1033  1039  ROOT   176      skills  I-SSkill
# 189  189   1104  1109  ROOT   189       field  I-HSkill
#     id  start  end   dep  head      tokens     label
# 17  17    120  127  ROOT    17     analisa  B-SSkill
# 67  67    471  481  ROOT    67  Monitoring  B-HSkill
#     id  start  end   dep  head       tokens     label
# 23  23    136  147  ROOT    23  pertumbuhan  B-SSkill
# 29  29    183  187  ROOT    29         data  B-HSkill
# 77  77    500  506  ROOT    77       sistem  B-HSkill
# 78  78    507  513  ROOT    78       Oracle    B-Tech
#       id  start  end   dep  head     tokens     label
# 46    46    285  289  ROOT    46       flow  I-HSkill
# 51    51    301  305  ROOT    51       data  B-HSkill
# 68    68    387  396  ROOT    68  usability  B-HSkill
# 101  101    571  578  ROOT   101    feature    B-Tech
# 114  114    638  644  ROOT   114     Skills  I-HSkill
# 118  118    664  671  ROOT   118    Testing  I-HSkill
# 120  120    673  681  ROOT   120   Lifeasia    B-Tech
# 122  122    683  686  ROOT   122        SQL    B-Tech
# 123  123    687  692  ROOT   123      Query    I-Tech
#       id  start   end   dep  head         tokens     label
# 30    30    178   186  ROOT    30       services  I-HSkill
# 31    31    187   195  ROOT    31       platform  I-HSkill
# 38    38    226   229  ROOT    38            our  B-HSkill
# 75    75    421   423  ROOT    75             we    B-Tech
# 83    83    458   465  ROOT    83        purpose  B-HSkill
# 94    94    515   518  ROOT    94            for  B-HSkill
# 149  149    792   799  ROOT   149        offline  B-HSkill
# 178  178    956   964  ROOT   178       Services  I-HSkill
# 185  185    984   987  ROOT   185            Our    B-Tech
# 249  249   1286  1291  ROOT   249          lines  I-HSkill
# 267  267   1403  1407  ROOT   267           data  I-HSkill
# 277  277   1454  1462  ROOT   277       platform  I-HSkill
# 297  297   1564  1571  ROOT   297        provide  B-HSkill
# 307  307   1628  1632  ROOT   307           data  I-HSkill
# 308  308   1633  1646  ROOT   308  visualization  I-HSkill
# 320  320   1674  1683  ROOT   320      analytics  B-HSkill
# 321  321   1684  1692  ROOT   321       projects  I-HSkill
# 327  327   1720  1724  ROOT   327           data  I-HSkill
# 353  353   1862  1870  ROOT   353       requests  I-HSkill
# 373  373   1955  1964  ROOT   373      Analytics  I-HSkill
# 378  378   1986  1992  ROOT   378         fields  I-HSkill
# 391  391   2051  2060  ROOT   391      analytics  I-HSkill
# 397  397   2086  2089  ROOT   397            SQL    B-Tech
# 401  401   2101  2108  ROOT   401        Ability  I-SSkill
# 406  406   2130  2134  ROOT   406           data  I-HSkill
# 407  407   2135  2139  ROOT   407           sets  I-HSkill
# 414  414   2181  2187  ROOT   414         skills  I-HSkill
# 432  432   2271  2276  ROOT   432          Spark    I-Tech
# 437  437   2294  2300  ROOT   437         Python    B-Tech
# 442  442   2318  2321  ROOT   442            Git    B-Tech
#       id  start  end   dep  head     tokens     label
# 57    57    381  385  ROOT    57       data  I-HSkill
# 112  112    737  741  ROOT   112       data  I-HSkill
# 114  114    754  757  ROOT   114        SQL  B-HSkill
# 116  116    762  771  ROOT   116  Microsoft    B-Tech
# 117  117    772  777  ROOT   117      Excel    I-Tech
#       id  start  end   dep  head      tokens     label
# 74    74    479  488  ROOT    74   Microsoft    B-Tech
# 75    75    489  495  ROOT    75      Office    I-Tech
# 77    77    497  501  ROOT    77        Word    B-Tech
# 79    79    503  508  ROOT    79       Excel    B-Tech
# 96    96    601  608  ROOT    96     analisa  B-SSkill
# 98    98    613  623  ROOT    98  ketelitian  B-SSkill
# 104  104    655  665  ROOT   104  komunikasi  B-SSkill
# 110  110    692  699  ROOT   110     dibawah  B-SSkill
# 111  111    700  707  ROOT   111     tekanan  I-SSkill
#       id  start  end   dep  head         tokens     label
# 12    12     72   80  ROOT    12       internet  I-HSkill
# 14    14     82   89  ROOT    14        program  B-HSkill
# 15    15     90   98  ROOT    15       internal  I-HSkill
# 34    34    201  205  ROOT    34           data  B-HSkill
# 56    56    336  344  ROOT    56       keuangan  B-SSkill
# 72    72    428  432  ROOT    72           Data  I-HSkill
# 90    90    528  536  ROOT    90       analisis  B-SSkill
# 102  102    600  613  ROOT   102  berkomunikasi  B-SSkill
#     id  start  end   dep  head     tokens     label
# 15  15     84   87  ROOT    15        SQL    B-Tech
# 17  17     89   95  ROOT    17     Python    B-Tech
# 20  20    101  105  ROOT    20       data  I-HSkill
# 21  21    106  114  ROOT    21   analysis  I-HSkill
# 22  22    115  120  ROOT    22      tools  I-HSkill
# 39  39    203  212  ROOT    39  Excellent  B-HSkill
# 41  41    227  233  ROOT    41     skills    I-Tech
#       id  start   end   dep  head       tokens     label
# 2      2     19    23  ROOT     2         Data  I-HSkill
# 12    12     79    83  ROOT    12         Data  I-HSkill
# 16    16    101   112  ROOT    16  Information  I-HSkill
# 29    29    188   197  ROOT    29    streaming  I-HSkill
# 31    31    202   213  ROOT    31  integration  I-HSkill
# ..   ...    ...   ...   ...   ...          ...       ...
# 328  328   1912  1918  ROOT   328       report  B-HSkill
# 345  345   1995  2004  ROOT   345    Economics  B-HSkill
# 347  347   2006  2014  ROOT   347     Computer  B-HSkill
# 350  350   2024  2035  ROOT   350  Information  B-HSkill
# 351  351   2036  2046  ROOT   351   Management  I-HSkill
#
# [61 rows x 7 columns]
#       id  start  end   dep  head           tokens     label
# 20    20    117  121  ROOT    20             data  I-HSkill
# 21    21    122  132  ROOT    21       processing  I-HSkill
# 23    23    134  137  ROOT    23              ETL    B-Tech
# 36    36    209  221  ROOT    36     applications  B-HSkill
# 63    63    371  386  ROOT    63  Troubleshooting  B-HSkill
# 74    74    443  454  ROOT    74      application  I-HSkill
# 91    91    544  550  ROOT    91           System  I-HSkill
# 93    93    552  556  ROOT    93             Math    B-Tech
# 98    98    584  594  ROOT    98       experience  I-HSkill
# 107  107    624  628  ROOT   107             Data  B-HSkill
# 108  108    629  639  ROOT   108       Processing  I-HSkill
# 113  113    661  664  ROOT   113              SQL    I-Tech
# 114  114    665  670  ROOT   114            Query    I-Tech
# 120  120    702  709  ROOT   120          Robotic  B-HSkill
# 152  152    901  908  ROOT   152          English    B-Tech
#       id  start   end   dep  head       tokens     label
# 5      5     26    37  ROOT     5  pembersihan  B-SSkill
# 9      9     54    58  ROOT     9         data  I-HSkill
# 30    30    219   223  ROOT    30         data  I-HSkill
# 52    52    386   391  ROOT    52        hasil    B-Tech
# 58    58    437   440  ROOT    58          tim  B-SSkill
# 95    95    690   694  ROOT    95         Data  B-HSkill
# 119  119    852   856  ROOT   119         data  B-HSkill
# 125  125    886   892  ROOT   125       Python    B-Tech
# 129  129    895   899  ROOT   129         SPSS    B-Tech
# 148  148   1032  1042  ROOT   148   komunikasi  B-SSkill
# 150  150   1047  1057  ROOT   150   presentasi  B-SSkill
# 168  168   1174  1181  ROOT   168      masalah  I-SSkill
# 173  173   1214  1218  ROOT   173         data  I-HSkill
#       id  start   end   dep  head        tokens     label
# 17    17    103   109  ROOT    17        sistem  B-HSkill
# 18    18    110   118  ROOT    18      database  I-HSkill
# 80    80    536   544  ROOT    80      database  B-HSkill
# 82    82    546   552  ROOT    82        sistem  B-HSkill
# 86    86    571   579  ROOT    86      analisis  B-HSkill
# 87    87    580   584  ROOT    87          data  I-HSkill
# 104  104    685   697  ROOT   104  mengevaluasi  B-SSkill
# 127  127    848   857  ROOT   127     informasi  B-HSkill
# 136  136    904   908  ROOT   136          Data  B-HSkill
# 161  161   1021  1030  ROOT   161     Microsoft    B-Tech
# 162  162   1031  1036  ROOT   162         Excel    B-Tech
# 168  168   1056  1061  ROOT   168         skill    B-Tech
# 169  169   1062  1069  ROOT   169       problem  B-HSkill
# 189  189   1185  1190  ROOT   189         jujur  B-SSkill
# 196  196   1221  1228  ROOT   196       dibawah  B-SSkill
# 197  197   1229  1236  ROOT   197       tekanan  I-SSkill
# 203  203   1275  1283  ROOT   203      analitis  B-SSkill
# 217  217   1373  1385  ROOT   217  menganalisis    B-Tech
#       id  start  end   dep  head         tokens     label
# 39    39    244  250  ROOT    39         desain  B-HSkill
# 52    52    336  343  ROOT    52        otomasi  B-HSkill
# 58    58    381  394  ROOT    58  berkoordinasi  B-SSkill
# 119  119    790  800  ROOT   119     komunikasi  B-SSkill
# 121  121    802  809  ROOT   121        analisa  B-SSkill
# 124  124    815  825  ROOT   124     presentasi  B-SSkill
#       id  start   end   dep  head       tokens     label
# 10    10     62    67  ROOT    10        Other  B-HSkill
# 41    41    238   245  ROOT    41      systems  I-HSkill
# 63    63    366   375  ROOT    63    solutions  I-HSkill
# 68    68    400   407  ROOT    68      clients  B-SSkill
# 73    73    431   435  ROOT    73         data  I-HSkill
# 76    76    447   451  ROOT    76         ways  I-HSkill
# 79    79    471   474  ROOT    79          can  I-HSkill
# 88    88    525   529  ROOT    88         data  I-HSkill
# 94    94    567   576  ROOT    94    solutions  I-HSkill
# 101  101    617   624  ROOT   101      process  I-HSkill
# 128  128    787   795  ROOT   128     business  I-HSkill
# 134  134    824   834  ROOT   134   validating  B-HSkill
# 137  137    851   859  ROOT   137     business  I-HSkill
# 163  163   1018  1027  ROOT   163    solutions  I-HSkill
# 174  174   1089  1098  ROOT   174    processes  I-HSkill
# 177  177   1111  1122  ROOT   177  improvement  I-HSkill
# 203  203   1255  1263  ROOT   203     partners  I-HSkill
# 207  207   1270  1280  ROOT   207   Developers  B-HSkill
# 246  246   1466  1472  ROOT   246       fields  I-HSkill
# 259  259   1531  1539  ROOT   259     Services  I-HSkill
# 260  260   1540  1548  ROOT   260     industry  I-HSkill
# 262  262   1550  1555  ROOT   262        Other  B-HSkill
# 282  282   1662  1670  ROOT   282     Analysis  I-HSkill
# 291  291   1706  1710  ROOT   291         self  B-SSkill
# 295  295   1720  1729  ROOT   295    motivated    B-Tech
# 347  347   2010  2017  ROOT   347      problem  B-HSkill
#       id  start  end   dep  head   tokens     label
# 0      0      0    3  ROOT     0      Job  B-HSkill
# 7      7     49   52  ROOT     7      tes  B-SSkill
# 27    27    146  149  ROOT    27      Job  B-HSkill
# 121  121    747  754  ROOT   121  HLOOKUP    B-Tech
# 143  143    883  889  ROOT   143   bahasa  B-SSkill
# 144  144    890  897  ROOT   144  inggris  I-SSkill
# 147  147    901  907  ROOT   147   Teliti  B-SSkill
# 156  156    954  958  ROOT   156     sama  I-SSkill
# 158  158    966  969  ROOT   158      tim  B-SSkill
# 163  163    992  995  ROOT   163      tes  B-SSkill
#       id  start  end   dep  head         tokens     label
# 77    77    485  494  ROOT    77      Microsoft    B-Tech
# 82    82    521  530  ROOT    82      berbahasa  B-SSkill
# 83    83    531  538  ROOT    83        Inggris  I-SSkill
# 90    90    578  585  ROOT    90        analisa  B-SSkill
# 92    92    590  603  ROOT    92  Interpersonal  B-HSkill
# 97    97    622  627  ROOT    97          Jujur  B-SSkill
# 99    99    629  637  ROOT    99       disiplin  B-SSkill
# 101  101    639  644  ROOT   101          tegas  B-SSkill
# 106  106    664  669  ROOT   106          keras  I-SSkill
# 109  109    681  685  ROOT   109           team  B-SSkill
# 112  112    700  710  ROOT   112     individual  B-SSkill
#       id  start   end   dep  head        tokens     label
# 22    22    122   127  ROOT    22         tasks  I-HSkill
# 35    35    189   200  ROOT    35   Summarizing  B-HSkill
# 44    44    252   260  ROOT    44      updating  B-HSkill
# 45    45    261   268  ROOT    45       Costing  I-HSkill
# 46    46    269   273  ROOT    46          data  I-HSkill
# 50    50    294   298  ROOT    50          data  I-HSkill
# 55    55    320   324  ROOT    55          data  I-HSkill
# 77    77    437   442  ROOT    77         which  B-SSkill
# 87    87    490   497  ROOT    87       systems  I-HSkill
# 88    88    498   508  ROOT    88    integrator  I-HSkill
# 106  106    609   616  ROOT   106       Service  B-HSkill
# 107  107    617   625  ROOT   107      Provider  I-HSkill
# 109  109    628   638  ROOT   109    Enterprise  B-HSkill
# 113  113    663   674  ROOT   113   Information  B-HSkill
# 114  114    675   683  ROOT   114      Security  I-HSkill
# 117  117    689   697  ROOT   117      Software  B-HSkill
# 118  118    698   707  ROOT   118     solutions  I-HSkill
# 133  133    795   801  ROOT   133        design  I-HSkill
# 136  136    811   821  ROOT   136    management  I-HSkill
# 138  138    823   833  ROOT   138    deployment  B-HSkill
# 140  140    835   846  ROOT   140   integration  B-HSkill
# 157  157    936   941  ROOT   157         tasks  I-HSkill
# 247  247   1441  1445  ROOT   247          data  I-HSkill
# 249  249   1447  1456  ROOT   249     providing  B-HSkill
# 262  262   1520  1528  ROOT   262      updating  B-HSkill
# 263  263   1529  1536  ROOT   263       Costing    I-Tech
# 264  264   1537  1541  ROOT   264          data  I-HSkill
# 277  277   1612  1616  ROOT   277          data  I-HSkill
# 279  279   1618  1627  ROOT   279     verifying  B-HSkill
# 280  280   1628  1635  ROOT   280       details  I-HSkill
# 288  288   1670  1678  ROOT   288      database  B-HSkill
# 296  296   1720  1725  ROOT   296         Leads    B-Tech
# 297  297   1726  1730  ROOT   297          data  I-HSkill
# 299  299   1732  1744  ROOT   299  streamlining  B-HSkill
# 323  323   1871  1878  ROOT   323       entries  I-HSkill
#     id  start  end   dep  head     tokens     label
# 59  59    324  328  ROOT    59       coal    B-Tech
# 61  61    331  334  ROOT    61        oil    B-Tech
# 80  80    462  471  ROOT    80  parameter  I-HSkill
#       id  start   end   dep  head         tokens     label
# 154  154   1043  1049  ROOT   154         Office    I-Tech
# 160  160   1073  1080  ROOT   160        program  B-HSkill
# 169  169   1123  1132  ROOT   169      berbahasa  B-SSkill
# 170  170   1133  1140  ROOT   170        Inggris  I-SSkill
# 178  178   1170  1175  ROOT   178          jujur  B-SSkill
# 180  180   1177  1185  ROOT   180       disiplin  B-SSkill
# 189  189   1237  1244  ROOT   189        analisa  B-SSkill
# 193  193   1256  1268  ROOT   193   berorientasi  B-SSkill
# 199  199   1300  1310  ROOT   199     komunikasi  B-SSkill
# 201  201   1315  1321  ROOT   201         relasi  B-HSkill
# 202  202   1322  1335  ROOT   202  interpersonal  B-SSkill
#       id  start   end   dep  head       tokens     label
# 4      4     14    17  ROOT     4          Key    B-Tech
# 25    25    124   133  ROOT    25    processes  B-HSkill
# 28    28    139   147  ROOT    28     analyzes  B-HSkill
# 29    29    148   152  ROOT    29         data  I-HSkill
# 44    44    254   258  ROOT    44         sets  I-HSkill
# 50    50    296   304  ROOT    50     insights  I-HSkill
# 57    57    344   350  ROOT    57       Gather    B-Tech
# 68    68    403   410  ROOT    68      Conduct    B-Tech
# 69    69    411   422  ROOT    69  statistical  B-HSkill
# 72    72    436   442  ROOT    72       create    B-Tech
# 77    77    458   467  ROOT    77    Visualize    B-Tech
# 78    78    468   472  ROOT    78         data  I-HSkill
# 80    80    479   484  ROOT    80        tools    I-Tech
# 82    82    490   497  ROOT    82      Tableau    I-Tech
# 85    85    505   507  ROOT    85           BI    I-Tech
# 87    87    509   511  ROOT    87           or    B-Tech
# 88    88    512   517  ROOT    88        Excel    B-Tech
# 102  102    598   609  ROOT   102  Collaborate    B-Tech
# 107  107    641   645  ROOT   107         data  I-HSkill
# 111  111    664   672  ROOT   111     insights  I-HSkill
# 115  115    684   688  ROOT   115         data  I-HSkill
# 116  116    689   696  ROOT   116      quality  I-HSkill
# 119  119    710   719  ROOT   119    databases  B-HSkill
# 131  131    770   778  ROOT   131     Computer  B-HSkill
# 136  136    799   804  ROOT   136        field  I-HSkill
# 142  142    829   837  ROOT   142     analysis  I-HSkill
# 143  143    838   843  ROOT   143        tools  I-HSkill
# 145  145    848   859  ROOT   145  programming  I-HSkill
# 150  150    877   880  ROOT   150          SQL    B-Tech
# 152  152    882   888  ROOT   152       Python    B-Tech
# 154  154    890   891  ROOT   154            R    B-Tech
# 159  159    903   913  ROOT   159   analytical  I-HSkill
# 163  163    936   942  ROOT   163       skills  I-SSkill
# 180  180   1041  1049  ROOT   180     findings  I-HSkill
#       id  start   end   dep  head         tokens     label
# 17    17     78    82  ROOT    17           Data  I-HSkill
# 21    21     94   101  ROOT    21        Invoice    I-Tech
# 34    34    161   168  ROOT    34        Digital  B-HSkill
# 35    35    169   176  ROOT    35        Process  I-HSkill
# 44    44    219   223  ROOT    44           Data    B-Tech
# 45    45    224   235  ROOT    45    Preparation  I-HSkill
# 73    73    382   390  ROOT    73       enabling  B-HSkill
# 90    90    501   514  ROOT    90  documentation  B-HSkill
# 105  105    610   621  ROOT   105    operational  I-HSkill
# 115  115    681   692  ROOT   115    initiatives  I-HSkill
# 151  151    939   947  ROOT   151       Document  I-HSkill
# 166  166   1046  1050  ROOT   166           team  B-SSkill
# 173  173   1077  1084  ROOT   173        Prepare    B-Tech
# 182  182   1122  1130  ROOT   182       database  I-HSkill
# 192  192   1199  1204  ROOT   192          tasks  I-HSkill
# 195  195   1208  1212  ROOT   195           Data  B-HSkill
# 201  201   1242  1248  ROOT   201         actual  B-SSkill
# 202  202   1249  1253  ROOT   202           data  I-HSkill
# 203  203   1254  1264  ROOT   203     pertaining  I-HSkill
# 229  229   1442  1449  ROOT   229        records  I-HSkill
# 244  244   1542  1551  ROOT   244      Equipment  B-HSkill
# 259  259   1638  1646  ROOT   259       optimize  B-HSkill
# 260  260   1647  1655  ROOT   260       resource  I-HSkill
# 273  273   1740  1747  ROOT   273        records  I-HSkill
# 280  280   1786  1798  ROOT   280   Requisitions  I-HSkill
# 305  305   1929  1936  ROOT   305        digital  I-HSkill
# 306  306   1937  1946  ROOT   306      processes  I-HSkill
# 309  309   1956  1962  ROOT   309         orders  I-HSkill
# 336  336   2132  2140  ROOT   336       insights  B-HSkill
# 344  344   2171  2175  ROOT   344           Data  B-HSkill
# 354  354   2239  2243  ROOT   354           data  I-HSkill
# 355  355   2244  2246  ROOT   355             to  I-HSkill
# 363  363   2301  2310  ROOT   363      processes  I-HSkill
#       id  start  end   dep  head         tokens     label
# 2      2     16   20  ROOT     2           Data    B-Tech
# 3      3     21   28  ROOT     3        Analyst  I-HSkill
# 8      8     52   57  ROOT     8          jawab  I-SSkill
# 16    16    105  109  ROOT    16           data  I-HSkill
# 35    35    237  241  ROOT    35           Data  B-HSkill
# 72    72    513  517  ROOT    72           Data  B-HSkill
# 109  109    739  743  ROOT   109           data  I-HSkill
# 116  116    781  785  ROOT   116           data  I-HSkill
# 120  120    807  815  ROOT   120       analitis  B-SSkill
# 127  127    865  869  ROOT   127           data  I-HSkill
# 140  140    947  960  ROOT   140  berkomunikasi  B-SSkill
#       id  start   end   dep  head           tokens     label
# 14    14     83    89  ROOT    14           skills  I-HSkill
# 19    19    107   114  ROOT    19          written    B-Tech
# 23    23    128   136  ROOT    23         Mandarin    B-Tech
# 46    46    242   251  ROOT    46        providing  B-HSkill
# 47    47    252   256  ROOT    47             data  I-HSkill
# 50    50    264   272  ROOT    50         insights  I-HSkill
# 52    52    274   283  ROOT    52        strategic  B-HSkill
# 53    53    284   299  ROOT    53  recommendations  I-HSkill
# 55    55    301   304  ROOT    55              and  B-HSkill
# 67    67    381   392  ROOT    67      effectively  B-SSkill
# 119  119    676   679  ROOT   119              BOC    B-Tech
# 121  121    681   684  ROOT   121              BOD    B-Tech
# 140  140    779   785  ROOT   140           handle  B-HSkill
# 145  145    820   829  ROOT   145        materials  I-HSkill
# 150  150    842   845  ROOT   150              the  B-HSkill
# 193  193   1148  1153  ROOT   193            plans  I-HSkill
# 195  195   1155  1166  ROOT   195      itineraries    B-Tech
# 201  201   1185  1194  ROOT   201        compiling  B-HSkill
# 202  202   1195  1204  ROOT   202        documents  I-HSkill
# 219  219   1288  1295  ROOT   219          various  B-HSkill
# 222  222   1309  1318  ROOT   222        fostering  B-HSkill
# 223  223   1319  1332  ROOT   223    collaboration  I-HSkill
# 226  226   1347  1360  ROOT   226    communication  I-HSkill
# 234  234   1395  1404  ROOT   234        according  I-HSkill
# 259  259   1531  1541  ROOT   259       dashboards  B-HSkill
# 265  265   1567  1578  ROOT   265      performance  I-HSkill
# 275  275   1611  1621  ROOT   275       functional  B-HSkill
# 276  276   1622  1630  ROOT   276         projects  I-HSkill
# 280  280   1648  1656  ROOT   280         delivery  I-HSkill
# 292  292   1722  1733  ROOT   292      documenting  B-HSkill
# 293  293   1734  1742  ROOT   293         progress  I-HSkill
# 296  296   1757  1764  ROOT   296          updates  I-HSkill
# 312  312   1857  1869  ROOT   312     stakeholders  I-HSkill
# 316  316   1891  1895  ROOT   316             data  I-HSkill
# 332  332   1974  1982  ROOT   332         Business  B-HSkill
# 363  363   2143  2153  ROOT   363       Proficient  I-HSkill
# 367  367   2176  2182  ROOT   367           skills  I-HSkill
# 372  372   2200  2207  ROOT   372          written    B-Tech
# 376  376   2221  2229  ROOT   376         Mandarin    B-Tech
# 385  385   2261  2269  ROOT   385         multiple  B-HSkill
# 394  394   2328  2338  ROOT   394       analytical  I-HSkill
# 395  395   2339  2345  ROOT   395           skills  I-HSkill
# 402  402   2384  2388  ROOT   402             data  I-HSkill
# 406  406   2411  2419  ROOT   406         insights  I-HSkill
# 410  410   2433  2446  ROOT   410    communication  I-HSkill
# 413  413   2464  2470  ROOT   413           skills  I-HSkill
# 433  433   2598  2606  ROOT   433         external  I-HSkill
# 441  441   2660  2671  ROOT   441      information  I-HSkill
# 449  449   2709  2724  ROOT   449  collaboratively    I-Tech
#       id  start   end   dep  head            tokens     label
# 3      3     20    22  ROOT     3                BI    B-Tech
# 17    17     89    93  ROOT    17              Data  B-HSkill
# 18    18     94   102  ROOT    18          Modeling  I-HSkill
# 22    22    107   109  ROOT    22                UI    B-Tech
# 27    27    131   138  ROOT    27           Problem  B-HSkill
# ..   ...    ...   ...   ...   ...               ...       ...
# 614  614   3656  3660  ROOT   614              data  I-HSkill
# 622  622   3706  3714  ROOT   622          jaringan  B-HSkill
# 662  662   3975  3991  ROOT   662  mengidentifikasi  B-HSkill
# 702  702   4238  4244  ROOT   702            visual  B-HSkill
# 715  715   4307  4313  ROOT   715            Visual  B-HSkill
#
# [93 rows x 7 columns]
#       id  start   end   dep  head         tokens     label
# 53    53    319   328  ROOT    53      Compiling    I-Tech
# 55    55    330   338  ROOT    55       updating  B-HSkill
# ...
# 114  114    636   647  ROOT   114  Informatics  B-HSkill
# 115  115    648   659  ROOT   115  Engineering  I-HSkill
# 124  124    698   707  ROOT   124    Microsoft    B-Tech
# 125  125    708   713  ROOT   125        Excel    I-Tech
# 127  127    715   719  ROOT   127         SPSS    B-Tech
# 129  129    724   735  ROOT   129  programming  B-HSkill
# 133  133    753   756  ROOT   133          VBA    B-Tech
# 135  135    758   762  ROOT   135         SPSS    B-Tech
# 137  137    764   770  ROOT   137       Python    B-Tech
# 150  150    829   839  ROOT   150   processing  I-HSkill
# 160  160    894   900  ROOT   160       skills    I-Tech
# 162  162    902   912  ROOT   162   analytical  B-HSkill
# 164  164    917   926  ROOT   164    numerical  B-HSkill
# 165  165    927   933  ROOT   165       skills    I-Tech
# 167  167    935   942  ROOT   167      problem  B-HSkill
# 168  168    943   950  ROOT   168      solving  I-SSkill
# 178  178    999  1010  ROOT   178  negotiation  B-SSkill
# 179  179   1011  1017  ROOT   179       skills  B-SSkill
# 183  183   1032  1038  ROOT   183       detail  B-SSkill
#       id  start  end   dep  head      tokens     label
# 61    61    415  425  ROOT    61  komunikasi  B-SSkill
# 100  100    651  661  ROOT   100  Komunikasi  B-SSkill
# 106  106    682  689  ROOT   106     Inggris  I-SSkill
# 110  110    703  708  ROOT   110       Excel    B-Tech
#       id  start   end   dep  head      tokens     label
# 57    57    357   365  ROOT    57    Checking  I-HSkill
# 135  135    840   850  ROOT   135  monitoring  B-HSkill
# 154  154    952   960  ROOT   154    terutama  B-SSkill
# 238  238   1468  1473  ROOT   238       jawab  I-SSkill
# 257  257   1581  1587  ROOT   257      Credit  B-HSkill
# 277  277   1730  1737  ROOT   277     analisa  B-SSkill
# 283  283   1771  1776  ROOT   283       Excel    B-Tech
# 286  286   1790  1799  ROOT   286   Microsoft    B-Tech
#       id  start   end   dep  head       tokens     label
# 5      5     38    41  ROOT     5          Job    B-Tech
# 8      8     59    61  ROOT     8           As    B-Tech
# 12    12     79    83  ROOT    12         Data  I-HSkill
# 22    22    138   142  ROOT    22         data  I-HSkill
# 31    31    197   200  ROOT    31          the  B-HSkill
# 39    39    245   249  ROOT    39         data  B-HSkill
# 40    40    250   260  ROOT    40   collection  I-HSkill
# 42    42    262   269  ROOT    42      sorting  B-HSkill
# 70    70    406   410  ROOT    70         team  B-SSkill
# 99    99    552   560  ROOT    99     organize    B-Tech
# 104  104    584   588  ROOT   104         data  I-HSkill
# 118  118    645   653  ROOT   118     learning  I-HSkill
# 131  131    732   740  ROOT   131     labeling  I-HSkill
# 135  135    761   766  ROOT   135        model  B-HSkill
# 151  151    845   847  ROOT   151           AI  B-HSkill
# 155  155    865   874  ROOT   155    processes  I-HSkill
# 157  157    879   890  ROOT   157  algorithmic  B-HSkill
# 158  158    891   900  ROOT   158    processes  I-HSkill
# 174  174    995   999  ROOT   174         Text    B-Tech
# 230  230   1291  1300  ROOT   230    knowledge    I-Tech
# 251  251   1396  1403  ROOT   251      reading    B-Tech
# 292  292   1614  1622  ROOT   292     analysis  I-HSkill
# 314  314   1721  1725  ROOT   314         data  I-HSkill
#       id  start   end   dep  head          tokens     label
# 19    19    123   128  ROOT    19           field  I-HSkill
# 27    27    157   164  ROOT    27         machine  I-HSkill
# 30    30    175   183  ROOT    30        software  B-HSkill
# 31    31    184   195  ROOT    31     engineering  I-HSkill
# 42    42    235   242  ROOT    42         machine  I-HSkill
# 46    46    275   282  ROOT    46         PyTorch    B-Tech
# 48    48    283   286  ROOT    48             etc    B-Tech
# 55    55    313   322  ROOT    55       platforms  I-HSkill
# 57    57    324   327  ROOT    57             AWS    B-Tech
# 59    59    329   334  ROOT    59           Azure    B-Tech
# 61    61    336   342  ROOT    61          Google    B-Tech
# 62    62    343   348  ROOT    62           Cloud    I-Tech
# 66    66    360   362  ROOT    66              ML    B-Tech
# 67    67    363   371  ROOT    67        services  I-HSkill
# 74    74    407   413  ROOT    74          Docker    B-Tech
# 76    76    415   425  ROOT    76      Kubernetes    B-Tech
# 86    86    478   483  ROOT    86           tools  I-HSkill
# 90    90    493   496  ROOT    90             DVC    B-Tech
# 104  104    558   569  ROOT   104     Familiarity    B-Tech
# 109  109    599   608  ROOT   109       practices  I-HSkill
# 114  114    620   625  ROOT   114           build  B-HSkill
# 118  118    640   647  ROOT   118         machine  I-HSkill
# 120  120    657   671  ROOT   120  infrastructure  I-HSkill
# 134  134    752   762  ROOT   134      deployment  I-HSkill
# 151  151    868   877  ROOT   151       Engineers  I-HSkill
# 153  153    881   890  ROOT   153       integrate  I-HSkill
# 154  154    891   893  ROOT   154              ML  I-HSkill
# 165  165    948   951  ROOT   165             for  I-HSkill
# 177  177   1021  1031  ROOT   177      addressing  B-HSkill
# 186  186   1068  1075  ROOT   186         quality  I-HSkill
# 199  199   1143  1151  ROOT   199        optimize  B-HSkill
# 200  200   1152  1157  ROOT   200           cloud  I-HSkill
# 202  202   1164  1166  ROOT   202              ML    B-Tech
# 217  217   1257  1266  ROOT   217       practices  I-SSkill
#       id  start   end   dep  head          tokens     label
# 7      7     41    52  ROOT     7     Development  I-HSkill
# 10    10     55    59  ROOT    10            Data  B-HSkill
# 20    20    111   121  ROOT    20      Compliance  B-HSkill
# 33    33    188   198  ROOT    33      Experience  B-HSkill
# 36    36    204   208  ROOT    36            Join    B-Tech
# 63    63    364   367  ROOT    63             our  I-HSkill
# 100  100    582   593  ROOT   100     Development  I-HSkill
# 102  102    595   599  ROOT   102            Data  B-HSkill
# 110  110    649   659  ROOT   110      Compliance  B-HSkill
# 119  119    707   721  ROOT   119  Qualifications  I-HSkill
# 123  123    739   743  ROOT   123            Join    B-Tech
# 136  136    791   803  ROOT   136    optimization  B-HSkill
# 153  153    895   906  ROOT   153     performance  I-HSkill
# 155  155    908   917  ROOT   155       analyzing  B-HSkill
# 161  161    947   959  ROOT   161    satisfaction  I-HSkill
# 163  163    961   971  ROOT   163      engagement  B-HSkill
# 170  170   1002  1010  ROOT   170        Identify  B-HSkill
# 183  183   1090  1097  ROOT   183         changes  I-HSkill
# 193  193   1145  1153  ROOT   193        customer  B-HSkill
# 194  194   1154  1159  ROOT   194           needs  I-HSkill
# 198  198   1177  1185  ROOT   198        insights  I-HSkill
# 200  200   1191  1194  ROOT   200             can  I-HSkill
# 202  202   1202  1209  ROOT   202         product    B-Tech
# 214  214   1279  1288  ROOT   214       proposals  I-HSkill
# 216  216   1293  1296  ROOT   216             new  I-HSkill
# 229  229   1378  1387  ROOT   229       marketing  B-HSkill
# 244  244   1476  1480  ROOT   244            data  I-HSkill
# 248  248   1504  1512  ROOT   248        insights  I-HSkill
# 260  260   1573  1583  ROOT   260      dashboards  B-HSkill
# 277  277   1674  1683  ROOT   277       marketing  B-HSkill
# 294  294   1777  1784  ROOT   294         vendors  I-HSkill
# 298  298   1804  1816  ROOT   298    integrations  I-HSkill
# 336  336   2059  2063  ROOT   336            data  I-HSkill
# 340  340   2078  2085  ROOT   340         provide  B-HSkill
# 341  341   2086  2094  ROOT   341        insights  I-HSkill
# 363  363   2204  2215  ROOT   363     performance  I-HSkill
# 374  374   2279  2292  ROOT   374   communication  B-HSkill
# 375  375   2293  2299  ROOT   375          skills  I-SSkill
# 401  401   2446  2454  ROOT   401        delivery  I-HSkill
# 418  418   2548  2557  ROOT   418       platforms  I-HSkill
# 446  446   2681  2689  ROOT   446        analysis  I-HSkill
# 449  449   2701  2711  ROOT   449      management  I-HSkill
# 453  453   2733  2741  ROOT   453        services  I-HSkill
# 475  475   2866  2871  ROOT   475           Excel    B-Tech
# 478  478   2881  2889  ROOT   478        analysis    B-Tech
# 479  479   2890  2895  ROOT   479           tools  I-HSkill
# 483  483   2903  2906  ROOT   483             SQL    B-Tech
# 507  507   3023  3027  ROOT   507            team  B-SSkill
# 518  518   3079  3081  ROOT   518              an    B-Tech
#       id  start  end   dep  head        tokens     label
# 0      0      0    3  ROOT     0           Job  B-HSkill
# 16    16    116  124  ROOT    16      provided  I-HSkill
# 33    33    225  233  ROOT    33      relevant  B-HSkill
# 58    58    409  419  ROOT    58    activities  I-HSkill
# 99    99    619  631  ROOT    99  verification  I-HSkill
# 108  108    672  681  ROOT   108     Microsoft  B-HSkill
# 109  109    682  686  ROOT   109          Word    I-Tech
# 111  111    688  693  ROOT   111         Excel    B-Tech
# 113  113    695  700  ROOT   113         Power    B-Tech
# 118  118    715  719  ROOT   118          good  B-HSkill
# 128  128    771  775  ROOT   128          task  I-HSkill
#       id  start   end   dep  head        tokens     label
# 0      0      0     3  ROOT     0           Job  B-HSkill
# 51    51    267   270  ROOT    51           Why    B-Tech
# 62    62    325   337  ROOT    62  deliverables  I-HSkill
# 83    83    469   471  ROOT    83            to  I-HSkill
# 85    85    480   483  ROOT    85           our  I-HSkill
# 86    86    484   491  ROOT    86       project  B-HSkill
# 87    87    492   500  ROOT    87      delivery  I-HSkill
# 91    91    524   533  ROOT    91     processes  I-HSkill
# 114  114    687   696  ROOT   114     materials  I-HSkill
# 121  121    732   735  ROOT   121           our  I-HSkill
# 144  144    864   866  ROOT   144            of  B-HSkill
# 146  146    879   889  ROOT   146    technology  I-HSkill
# 148  148    891   901  ROOT   148    accounting  B-HSkill
# 155  155    933   941  ROOT   155      relevant  B-HSkill
# 166  166    982   989  ROOT   166       working  B-HSkill
# 173  173   1022  1025  ROOT   173           use  I-HSkill
# 177  177   1047  1055  ROOT   177      software  I-HSkill
# 181  181   1065  1074  ROOT   181     Microsoft    B-Tech
# 199  199   1161  1164  ROOT   199           new  B-SSkill
# 202  202   1179  1185  ROOT   202        skills  I-SSkill
# 217  217   1242  1251  ROOT   217     practical  B-SSkill
# 218  218   1252  1258  ROOT   218        skills  I-HSkill
# 233  233   1329  1336  ROOT   233       network  I-HSkill
# 241  241   1379  1389  ROOT   241    successful  I-HSkill
#       id  start  end   dep  head       tokens     label
# 20    20    130  140  ROOT    20   scheduling  B-HSkill
# 32    32    223  226  ROOT    32          key  I-HSkill
# 33    33    227  238  ROOT    33  performance  I-HSkill
# 41    41    278  288  ROOT    41   efficiency  I-HSkill
# 58    58    386  393  ROOT    58      metrics  I-HSkill
# 61    61    405  413  ROOT    61     insights  I-HSkill
# 94    94    592  599  ROOT    94      process  I-HSkill
# 98    98    626  636  ROOT    98   management  I-HSkill
# 99    99    637  646  ROOT    99    practices  I-HSkill
# 114  114    726  734  ROOT   114     analysts  I-HSkill
#     id  start  end   dep  head      tokens     label
# 4    4     33   43  ROOT     4  Technology  I-HSkill
# 14  14     82   87  ROOT    14       apply  I-HSkill
# 19  19    106  111  ROOT    19       Excel    B-Tech
# 20  20    112  115  ROOT    20         VBA    B-Tech
# 22  22    117  126  ROOT    22   Microsoft    B-Tech
# 23  23    127  133  ROOT    23      Office    I-Tech
# 25  25    135  140  ROOT    25       Excel    B-Tech
# 27  27    142  146  ROOT    27        Word    B-Tech
# 49  49    248  258  ROOT    49  internship  I-HSkill
#     id  start  end   dep  head tokens     label
# 18  18    133  137  ROOT    18   data  I-HSkill
#       id  start   end   dep  head        tokens     label
# 40    40    194   205  ROOT    40   Information  B-HSkill
# 41    41    206   216  ROOT    41    Technology  I-HSkill
# 46    46    231   236  ROOT    46         field  I-HSkill
# 55    55    276   284  ROOT    55      software  B-HSkill
# 64    64    320   328  ROOT    64      database  B-HSkill
# 65    65    329   339  ROOT    65    management  I-HSkill
# 68    68    343   349  ROOT    68        Proven    B-Tech
# 90    90    495   501  ROOT    90        skills  I-HSkill
# 106  106    595   605  ROOT   106    analytical  I-HSkill
# 108  108    607   614  ROOT   108       problem  B-HSkill
# 122  122    683   692  ROOT   122     processes  I-HSkill
# 124  124    694   703  ROOT   124     workflows  B-HSkill
# 127  127    709   716  ROOT   127       systems  I-HSkill
# 140  140    788   793  ROOT   140         teams  I-HSkill
# 144  144    813   825  ROOT   144  requirements  I-HSkill
# 155  155    893   896  ROOT   155           the  B-HSkill
# 158  158    905   912  ROOT   158       testing  B-HSkill
# 180  180   1028  1032  ROOT   180          data  I-HSkill
# 183  183   1044  1052  ROOT   183      insights  I-HSkill
#       id  start   end   dep  head        tokens     label
# 20    20    159   168  ROOT    20     mengawasi  B-SSkill
# 21    21    169   176  ROOT    21       operasi  I-HSkill
# 111  111    828   835  ROOT   111       standar  B-HSkill
# 119  119    875   881  ROOT   119        Office    I-Tech
# 121  121    883   891  ROOT   121      database  B-HSkill
# 128  128    935   945  ROOT   128    komunikasi  B-SSkill
# 137  137    994  1004  ROOT   137    organisasi  B-SSkill
# 139  139   1009  1021  ROOT   139  kepemimpinan  B-SSkill
#     id  start  end   dep  head       tokens     label
# 27  27    180  184  ROOT    27         data  I-HSkill
# 36  36    233  237  ROOT    36         data  B-HSkill
# 73  73    506  517  ROOT    73  Performance  I-HSkill
#       id  start  end   dep  head        tokens     label
# 18    18    128  138  ROOT    18    konsultasi  B-SSkill
# 44    44    343  355  ROOT    44  implementasi  I-HSkill
# 91    91    719  727  ROOT    91      jawabnya  I-SSkill
# 99    99    779  789  ROOT    99    konsultasi  B-SSkill
# 112  112    886  894  ROOT   112      jawabnya  I-SSkill
#     id  start  end   dep  head      tokens     label
# 40  40    194  204  ROOT    40  Management  I-HSkill
# 41  41    205  210  ROOT    41       tools  I-HSkill
# 43  43    212  216  ROOT    43        Jira    B-Tech
# 47  47    233  234  ROOT    47           :    I-Tech
# 60  60    316  326  ROOT    60  functional  B-HSkill
# 91  91    524  530  ROOT    91      Design  I-HSkill
# 92  92    531  539  ROOT    92    Document  I-HSkill
#                                 Title                       Company  \
# 0                        Data Analyst          Yayasan Hutan Tropis
# 1                        DATA ANALYST        PT Karya Anugerah Jaya
# 2         Data Analyst Jr. Specialist  PT Bussan Auto Finance (BAF)
# 3                        Data Analyst                  PT SMART,Tbk
# 4  Data Analyst - ERP Staff (JAKARTA)           PT Allure Alluminio
#
#                                          Description  \
# 0  Data Analyst: Collect, clean and analyze infor...
# 1  KUALIFIKASI :: DESKRIPSI PEKERJAAN :: NOTE : P...
# 2  Job Description : : Qualification : : Job Desc...
# 3  Job Description Summary:: Job Description:: Jo...
# 4  ERP(Dynamics 365 Business Central): Bersedia d...
#
#                                             B-HSkill  \
# 0  [dynamic environment information innovate, our...
# 1   [familiar, data analyst data, accurate, program]
# 2                                   [job data, tool]
# 3  [supplier desktop, reliable verification descr...
# 4                               [mengolah, analisis]
#
#                                             B-SSkill                    B-Tech
# 0                                           [bahasa]          [palm, vba, soy]
# 1  [jujur, interpersonal, teliti, komunikasi, ber...  [microsoft office, note]
# 2                                  [tim, komunikasi]              [excel, sql]
# 3                                                  0                         0
# 4                         [mandiri, tim, komunikasi]                         0

# %%
results_df
# Out:
#                                               B-HSkill  \
# 0    [dynamic environment information innovate, our...
# 1     [familiar, data analyst data, accurate, program]
# 2                                     [job data, tool]
# 3    [supplier desktop, reliable verification descr...
# 4                                 [mengolah, analisis]
# ..                                                 ...
# 123  [information technology field, database manage...
# 124                                         [database]
# 125                                 [data performance]
# 126                                                NaN
# 127                       [functional design document]
#
#                                               B-SSkill  \
# 0                                             [bahasa]
# 1    [jujur, interpersonal, teliti, komunikasi, ber...
# 2                                    [tim, komunikasi]
# 3                                                  NaN
# 4                           [mandiri, tim, komunikasi]
# ..                                                 ...
# 123                                                NaN
# 124             [kepemimpinan, komunikasi, organisasi]
# 125                                                NaN
# 126                              [konsultasi jawabnya]
# 127                                                NaN
#
#                        B-Tech
# 0            [palm, vba, soy]
# 1    [microsoft office, note]
# 2                [excel, sql]
# 3                         NaN
# 4                         NaN
# ..                        ...
# 123                       NaN
# 124                       NaN
# 125                       NaN
# 126                       NaN
# 127                  [jira :]
#
# [128 rows x 3 columns]

# %%
job_desc.head()
# Out:
#                                 Title                       Company  \
# 0                        Data Analyst          Yayasan Hutan Tropis
# 1                        DATA ANALYST        PT Karya Anugerah Jaya
# 2         Data Analyst Jr. Specialist  PT Bussan Auto Finance (BAF)
# 3                        Data Analyst                  PT SMART,Tbk
# 4  Data Analyst - ERP Staff (JAKARTA)           PT Allure Alluminio
#
#                                          Description  \
# 0  Data Analyst: Collect, clean and analyze infor...
# 1  KUALIFIKASI :: DESKRIPSI PEKERJAAN :: NOTE : P...
# 2  Job Description : : Qualification : : Job Desc...
# 3  Job Description Summary:: Job Description:: Jo...
# 4  ERP(Dynamics 365 Business Central): Bersedia d...
#
#                                             B-HSkill  \
# 0  [dynamic environment information innovate, our...
# 1   [familiar, data analyst data, accurate, program]
# 2                                   [job data, tool]
# 3  [supplier desktop, reliable verification descr...
# 4                               [mengolah, analisis]
#
#                                             B-SSkill                    B-Tech
# 0                                           [bahasa]          [palm, vba, soy]
# 1  [jujur, interpersonal, teliti, komunikasi, ber...  [microsoft office, note]
# 2                                  [tim, komunikasi]              [excel, sql]
# 3                                                  0                         0
# 4                         [mandiri, tim, komunikasi]                         0

# %%
import spacy
from spacy import displacy

item = job_desc.iloc[0]['Description']  

doc = model_ner(item)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Data Analyst: Collect, clean and analyze
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     information
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
# : Summarize data insights: Collaborate: improve our internal
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     processes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
# : Location: Other information: With most
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-HSkill</span>
# </mark>
#  our staff operating directly on the ground where the issues are, we work with our mem-bers and partners to make value chains an engine of prosperity for communities and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ecosystems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
# . We see a world where forests are a boundless source of materials and a home for biodiversity; com-munities see their rights respected and have opportunities to develop; workers are seen as productive partners, and agriculture becomes the instrument to feed a hungry planet and keep our climate stable. As a Data Analyst, your primary responsibilities are to:   In this role, you’ll be managing large,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     complex
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-HSkill</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-Tech</span>
# </mark>
# , ensuring their integrity and quality while creating clear and compelling reports. Your
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     expertise
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Excel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-Tech</span>
# </mark>
# , including advanced skills in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     macros
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-Tech</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     will
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-HSkill</span>
# </mark>
#  be essential in automating and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     optimizing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-HSkill</span>
# </mark>
#  our
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     processes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
# . Plus, your experience with tools like
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PowerPoint
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-Tech</span>
# </mark>
#  and Tableau will help you craft
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     impactful
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#  presentations that tell a story. We value a collaborative mindset and are looking for someone who can work independently while integrating
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seamlessly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#  with our diverse, multicultural team. Your strong communication
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     skills
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#  and diplomatic approach will help you build strong relationships and navigate difficult conversations with ease. If you’re a curious problem-solver who thrives in a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dynamic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-HSkill</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     environment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-HSkill</span>
# </mark>
#  and is eager to contribute to our team’s success, we’d love to have you on board. Let’s work together to create a more sustainable future! Language skills Location Other
# <mark class="entity" style="background: #ddd;

# %%
results_df
# Out:
#                                               B-HSkill  \
# 0    [dynamic environment information innovate, our...
# 1     [familiar, data analyst data, accurate, program]
# 2                                     [job data, tool]
# 3    [supplier desktop, reliable verification descr...
# 4                                 [mengolah, analisis]
# ..                                                 ...
# 123  [information technology field, database manage...
# 124                                         [database]
# 125                                 [data performance]
# 126                                                NaN
# 127                       [functional design document]
#
#                                               B-SSkill  \
# 0                                             [bahasa]
# 1    [jujur, interpersonal, teliti, komunikasi, ber...
# 2                                    [tim, komunikasi]
# 3                                                  NaN
# 4                           [mandiri, tim, komunikasi]
# ..                                                 ...
# 123                                                NaN
# 124             [kepemimpinan, komunikasi, organisasi]
# 125                                                NaN
# 126                              [konsultasi jawabnya]
# 127                                                NaN
#
#                        B-Tech
# 0            [palm, vba, soy]
# 1    [microsoft office, note]
# 2                [excel, sql]
# 3                         NaN
# 4                         NaN
# ..                        ...
# 123                       NaN
# 124                       NaN
# 125                       NaN
# 126                       NaN
# 127                  [jira :]
#
# [128 rows x 3 columns]

# %%
results_df.to_excel('./Data/skills_DA.xlsx', index=False, engine='openpyxl')

# %%
skill_list = results_df['B-Tech'].explode().tolist()

# %%
skill_list2 = results_df['B-Tech'].explode().tolist()

# %%
len(skill_list2)
# Out:
# 582

# %%
skill_list = list(set(skill_list))

# %%
#exp = pd.DataFrame(skill_list2, columns=['Skills'])  # Create a DataFrame
#exp.to_excel('skill_list2.xlsx', index=False)  # Export to Excel

# %% [markdown]
# Manually Edit the list !

# %%
data = pd.read_excel('./Data/skill_list.xlsx')

# %%
data
# Out:
#                         Skills
# 0                          db2
# 1                 google cloud
# 2                      job etl
# 3                         unix
# 4              microsoft excel
# ..                         ...
# 188  exploratory data analysis
# 189    artificial intelligence
# 190                      ci cd
# 191      google cloud platform
# 192                  modelling
#
# [193 rows x 1 columns]

# %%
from collections import Counter

counts = Counter(skill_list2)
df = pd.DataFrame(counts.items(), columns=['Item', 'Count'])
df = df.dropna()

# %%
df.sort_values('Count', ascending =False).head(50)
# Out:
#                  Item  Count
# 6                 sql     19
# 5               excel     17
# 18             python     12
# 66            written      6
# 57          microsoft      6
# 3    microsoft office      5
# 8     microsoft excel      5
# 26                etl      4
# 92         sql server      4
# 61                key      4
# 75               data      4
# 54               spss      4
# 23                aws      4
# 100             mysql      4
# 40             update      4
# 162               uat      3
# 144        postgresql      3
# 1                 vba      3
# 41             oracle      3
# 84            tableau      3
# 46               word      3
# 20             hadoop      3
# 174              java      3
# 9          tableau bi      3
# 89                  r      3
# 154           asp.net      2
# 76                api      2
# 47                etc      2
# 79                 bi      2
# 51         javascript      2
# 188               tsd      2
# 78              power      2
# 161             visio      2
# 68          itinerary      2
# 176               job      2
# 73              query      2
# 182              .net      2
# 91             proven      2
# 62            conduct      2
# 163               uml      2
# 69                bod      2
# 64             gather      2
# 165               fsd      2
# 65                boc      2
# 14         experience      2
# 126              html      2
# 19            pytorch      2
# 25         tensorflow      2
# 27              azure      2
# 28       google cloud      2

# %%
#df.to_excel('./Data/skill_frequency.xlsx', index=False)

# %%
import re
pattern = r'(\d+)[\s-]*(\d*)\s*(?:years?|tahun|th|yrs?|experience|pengalaman)'

def extract_experience(text):
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        if match.group(2):
            return f"{match.group(1)}-{match.group(2)} years"
        else:
            return f"{match.group(1)} years"
    else:
        if re.search(r'fresh\s*graduate', text, re.IGNORECASE):
            return "Fresh Graduate"
        return None

# %%
job_desc['Experience Required'] = job_desc['Description'].apply(extract_experience)

# %%
job_desc['Experience Required'].unique()
# Out:
# array(['3-5 years', None, '30 years', '45 years', '25-35 years',
#        '2 years', '3 years', '5 years', '35 years', '4 years',
#        'Fresh Graduate', '2-5 years', '28 years', '1 years', '1-2 years',
#        '2-3 years', '20-30 years', '1-3 years', '15 years', '23-35 years',
#        '26 years', '27 years', '5-8 years', '25 years'], dtype=object)

# %%
unique_counts = job_desc['Experience Required'].value_counts()
unique_counts
# Out:
# 2 years           15
# 1 years           12
# 3 years            8
# 5 years            6
# 2-3 years          5
# 4 years            5
# 3-5 years          4
# Fresh Graduate     4
# 30 years           3
# 1-2 years          3
# 35 years           3
# 28 years           2
# 25 years           2
# 2-5 years          1
# 25-35 years        1
# 45 years           1
# 20-30 years        1
# 1-3 years          1
# 15 years           1
# 23-35 years        1
# 26 years           1
# 27 years           1
# 5-8 years          1
# Name: Experience Required, dtype: int64

# %%
def normalize_experience(experience):
    if experience is None:  # Check for None
        return np.nan
    if 'Fresh Graduate' in experience:
        return 0
    elif 'year' in experience:
        numbers = re.findall(r'\d+', experience)
        if len(numbers) == 1:
            return int(numbers[0])
        elif len(numbers) == 2:
            return (int(numbers[0]) + int(numbers[1])) / 2  # Average of the range
    return np.nan  # Return NaN for unexpected formats

# %%
job_desc['Normalized Experience'] = job_desc['Experience Required'].apply(normalize_experience)

# %%
bins = [-1, 0, 1, 2, 3, 5, np.inf]  # Adjust as needed
labels = ['Fresh Graduate', '1 Year', '1 - 2 Years', '2 - 3 Years', '3 - 5 Years', '5+ Years']

# Create a new column for binned categories
job_desc['Experience Category'] = pd.cut(job_desc['Normalized Experience'], bins=bins, labels=labels)

print(job_desc[['Experience Required', 'Normalized Experience', 'Experience Category']])
# Out:
#     Experience Required  Normalized Experience Experience Category
# 0             3-5 years                    4.0         3 - 5 Years
# 1                  None                    NaN                 NaN
# 2                  None                    NaN                 NaN
# 3                  None                    NaN                 NaN
# 4                  None                    NaN                 NaN
# ..                  ...                    ...                 ...
# 123                None                    NaN                 NaN
# 124             1 years                    1.0              1 Year
# 125                None                    NaN                 NaN
# 126            28 years                   28.0            5+ Years
# 127             2 years                    2.0         1 - 2 Years
#
# [128 rows x 3 columns]

# %%
job_desc['Experience Category']
# Out:
# 0      3 - 5 Years
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 123            NaN
# 124         1 Year
# 125            NaN
# 126       5+ Years
# 127    1 - 2 Years
# Name: Experience Category, Length: 128, dtype: category
# Categories (6, object): ['Fresh Graduate' < '1 Year' < '1 - 2 Years' < '2 - 3 Years' < '3 - 5 Years' < '5+ Years']

# %%
job_desc['Experience Category'].value_counts()
# Out:
# 1 - 2 Years       19
# 5+ Years          18
# 3 - 5 Years       16
# 2 - 3 Years       13
# 1 Year            12
# Fresh Graduate     4
# Name: Experience Category, dtype: int64

# %%
job_desc['Experience Category'] = job_desc['Experience Category'].astype(object)

# Replace NaN values with "Not Stated"
job_desc['Experience Category'] = job_desc['Experience Category'].fillna('Not Stated Specifically in Years')

# %%
job_desc['Experience Category'].value_counts()
# Out:
# Not Stated Specifically in Years    46
# 1 - 2 Years                         19
# 5+ Years                            18
# 3 - 5 Years                         16
# 2 - 3 Years                         13
# 1 Year                              12
# Fresh Graduate                       4
# Name: Experience Category, dtype: int64

# %%
job_desc[(job_desc['Experience Category'] == "Fresh Graduate")]
# Out:
#                                 Title                           Company  \
# 23   Subsurface Data Scientist Intern  PT Sorik Marapi Geothermal Power
# 24                      Data Engineer      PT Multipolar Technology Tbk
# 48           Marketing Insight Intern                  Pengiklan Anonim
# 104        Data Management Specialist            PT Andika Mitra Sejati
#
#                                            Description  \
# 23   Job Specification::   Job Specification: Assis...
# 24   Scope of Work:: Requirements:: Scope of Work: ...
# 48   PT. Pharos Indonesia: Marketing Insight Intern...
# 104  Requirement:  Tugas dan tanggung jawab: D3/ S1...
#
#                                               B-HSkill  \
# 23   [database software related, geophysics, job, e...
# 24   [information technology, computer, database, g...
# 48   [business, description marketing data data pro...
# 104                                                  0
#
#                                               B-SSkill  \
# 23                                   [problem solving]
# 24                                              [self]
# 48                                                   0
# 104  [bahasa inggris, berkomunikasi, administrasi, ...
#
#                                                 B-Tech Experience Required  \
# 23                                [geology, microsoft]      Fresh Graduate
# 24   [cloudera, hadoop, db2, etl, microsoft ssis, t...      Fresh Graduate
# 48                               [excel, python, spss]      Fresh Graduate
# 104                                                  0      Fresh Graduate
#
#      Normalized Experience Experience Category
# 23                     0.0      Fresh Graduate
# 24                     0.0      Fresh Graduate
# 48                     0.0      Fresh Graduate
# 104                    0.0      Fresh Graduate

# %%
#job_desc.to_excel('./Data/skill and experience.xlsx', index=False)

# %%
exp_category = pd.DataFrame(job_desc['Experience Category'].unique())

# %%
unique_experience = job_desc['Experience Category'].unique()

# %%
experience_weights = {
    'Fresh Graduate': 0,
    '1 Year': 1,
    '1 - 2 Years': 1.5,
    '2 - 3 Years': 2,
    '3 - 5 Years': 3,
    '5+ Years': 4
}

# Step 3: Create a new DataFrame with unique experience categories and their weights
exp_category = pd.DataFrame({
    'Experience Category': unique_experience,
    'Weight': [experience_weights.get(exp, None) for exp in unique_experience]
}).sort_values('Weight')

# Display the new DataFrame

# %%
exp_category.to_csv('./Data/exp_category.csv')
